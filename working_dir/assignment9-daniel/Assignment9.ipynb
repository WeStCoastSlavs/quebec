# %%
import pandas as pd
df2 = pd.read_csv('df2.csv', encoding='utf-8', index_col=0, header=0)

# %%
df2.out_links = df2.out_links.apply(lambda x: x.replace('[', ''))
df2.out_links = df2.out_links.apply(lambda x: x.replace(']', ''))
df2.out_links = df2.out_links.apply(lambda x: x.split(', '))
df2['link_num'] = df2.out_links.apply(lambda x: len(x))
df2 = df2.sort_values(by="link_num", ascending=False)

# %%
df2 = df2.drop_duplicates(subset = "name")

# %%
df2 = df2.set_index('name')

# %%
# df2 = df2.head(500)

# %%
len(df2)
# Out:
# 27493

# %%
diction = df2.to_dict()['out_links']

# %%
from time import time
def floydwarshall(graph):
 
    # Initialize dist and pred:
    # copy graph into dist, but add infinite where there is
    # no edge, and 0 in the diagonal
    start = time()
    dist = {}
#     pred = {}
    for u in graph.keys():
        dist[u] = {}
#         pred[u] = {}
        for v in graph.keys():
            dist[u][v] = 1000
            pred[u][v] = -1
        dist[u][u] = 0
        for neighbor in graph[u]:
            dist[u][neighbor] = 1
#             pred[u][neighbor] = u
            
    print(time() - start)
    
    diameter = 0
 
    for t in graph.keys():
        # given dist u to v, check if path u - t - v is shorter
        for u in graph.keys():
            for v in graph.keys():
                newdist = dist[u][t] + dist[t][v]
                if newdist < dist[u][v]:
                    dist[u][v] = newdist
#                   pred[u][v] = pred[t][v] 
                    # route new path through t
    
    print(time() - start)
 
    return dist, pred

# %%
# dist, pred = floydwarshall(diction)
# only_d = [l for key in dist.keys() for l in dist[key].values() if l < 1000]
# max(only_d)

# %%
import networkx as nx
G=nx.DiGraph(diction)

# %%
G.number_of_nodes()
# Out:
# 34965

# %%
G.number_of_edges()
# Out:
# 600288

# %%
G.edges()
# Out:
# [('Cear%C3%A1', 'Mato_Grosso_904c'),
#  ('Cear%C3%A1', 'Rondônia'),
#  ('Cear%C3%A1', 'Bahia'),
#  ('Cear%C3%A1', 'Brazil'),
#  ('Cear%C3%A1', 'Capital_(city)'),
#  ('Cear%C3%A1', 'Amazonas_(Brazil)_ad09'),
#  ('Cear%C3%A1', 'Roraima'),
#  ('Cear%C3%A1', 'Square_kilometre'),
#  ('Cear%C3%A1', 'Alagoas'),
#  ('Cear%C3%A1', 'Tourism'),
#  ('Cear%C3%A1', 'Maranhão'),
#  ('Cear%C3%A1', 'Governor'),
#  ('Cear%C3%A1', 'Atlantic_Ocean_570a'),
#  ('Cear%C3%A1', 'Sergipe'),
#  ('Cear%C3%A1', 'Coast'),
#  ('Cear%C3%A1', 'Brazilian_Federal_District_3729'),
#  ('Cear%C3%A1', 'Ceará'),
#  ('Cear%C3%A1', 'Rio_Grande_do_Norte_26f1'),
#  ('Cear%C3%A1', 'Piauí'),
#  ('Cear%C3%A1', 'Pará'),
#  ('Cear%C3%A1', 'Beach'),
#  ('Cear%C3%A1', 'São_Paulo_(state)_7787'),
#  ('Cear%C3%A1', 'ISO_3166-2_5396'),
#  ('Cear%C3%A1', 'States_of_Brazil_ac36'),
#  ('Cear%C3%A1', 'Rio_Grande_do_Sul_778a'),
#  ('Cear%C3%A1', 'Espírito_Santo_15c1'),
#  ('Cear%C3%A1', 'Acre_(state)'),
#  ('Cear%C3%A1', 'Amapá'),
#  ('Cear%C3%A1', 'Political_subdivision_of_Brazil_0915'),
#  ('Cear%C3%A1', 'Santa_Catarina_(state)_0425'),
#  ('Cear%C3%A1', 'Minas_Gerais_4450'),
#  ('Cear%C3%A1', 'Flags_of_Brazilian_states_8c9c'),
#  ('Cear%C3%A1', 'Tocantins_(state)'),
#  ('Cear%C3%A1', 'Population'),
#  ('Cear%C3%A1', 'Demonym'),
#  ('Cear%C3%A1', 'Goiás'),
#  ('Cear%C3%A1', 'Pernambuco'),
#  ('Cear%C3%A1', 'Paraná_(state)'),
#  ('Cear%C3%A1', 'Area'),
#  ('Cear%C3%A1', 'Mato_Grosso_do_Sul_60f7'),
#  ('Cear%C3%A1', 'Timezone'),
#  ('Cear%C3%A1', 'Paraíba'),
#  ('Cear%C3%A1', 'Rio_de_Janeiro_(state)_9b07'),
#  ('Utrecht_(province)', 'Province'),
#  ('Utrecht_(province)', 'Utrecht_(province)'),
#  ('Utrecht_(province)', 'Netherlands'),
#  ('Utrecht_(province)', 'Friesland'),
#  ('Utrecht_(province)', 'Groningen_(province)'),
#  ('Utrecht_(province)', 'Flevoland'),
#  ('Utrecht_(province)', 'Overijssel'),
#  ('Utrecht_(province)', 'Zeeland_(province)'),
#  ('Utrecht_(province)', 'North_Holland_f179'),
#  ('Utrecht_(province)', 'North_Brabant_49b9'),
#  ('Utrecht_(province)', 'Limburg_(Netherlands)_0066'),
#  ('Utrecht_(province)', 'South_Holland_8dc5'),
#  ('Utrecht_(province)', 'Drenthe'),
#  ('Utrecht_(province)', 'Provinces_of_the_Netherlands_e502'),
#  ('Utrecht_(province)', 'Guelders'),
#  ('Utrecht_(province)', 'Country'),
#  ('List_of_record_labels_starting_with_B_1151',
#   'List_of_record_labels_starting_with_D_10ad'),
#  ('List_of_record_labels_starting_with_B_1151',
#   'List_of_record_labels_starting_with_O_0fad'),
#  ('List_of_record_labels_starting_with_B_1151',
#   'List_of_record_labels_starting_with_E_39df'),
#  ('List_of_record_labels_starting_with_B_1151',
#   'List_of_record_labels_starting_with_Z_72b5'),
#  ('List_of_record_labels_starting_with_B_1151',
#   'List_of_record_labels_starting_with_B_1151'),
#  ('List_of_record_labels_starting_with_B_1151',
#   'List_of_record_labels_starting_with_K_6a2d'),
#  ('List_of_record_labels_starting_with_B_1151', 'List_of_record_labels'),
#  ('List_of_record_labels_starting_with_B_1151',
#   'List_of_record_labels_starting_with_P_21ac'),
#  ('List_of_record_labels_starting_with_B_1151',
#   'List_of_record_labels_starting_with_F_ade6'),
#  ('List_of_record_labels_starting_with_B_1151',
#   'List_of_record_labels_starting_with_C_ab91'),
#  ('List_of_record_labels_starting_with_B_1151',
#   'List_of_record_labels_starting_with_a_number'),
#  ('List_of_record_labels_starting_with_B_1151',
#   'List_of_record_labels_starting_with_G_4135'),
#  ('List_of_record_labels_starting_with_B_1151',
#   'List_of_record_labels_starting_with_M_94ac'),
#  ('List_of_record_labels_starting_with_B_1151',
#   'List_of_record_labels_starting_with_S_19fc'),
#  ('List_of_record_labels_starting_with_B_1151',
#   'List_of_record_labels_starting_with_X_502d'),
#  ('List_of_record_labels_starting_with_B_1151',
#   'List_of_record_labels_starting_with_J_43bd'),
#  ('List_of_record_labels_starting_with_B_1151',
#   'List_of_record_labels_starting_with_Q_9a9f'),
#  ('List_of_record_labels_starting_with_B_1151',
#   'List_of_record_labels_starting_with_H_3d6f'),
#  ('List_of_record_labels_starting_with_B_1151',
#   'List_of_record_labels_starting_with_I_b41a'),
#  ('List_of_record_labels_starting_with_B_1151',
#   'List_of_record_labels_starting_with_R_2602'),
#  ('List_of_record_labels_starting_with_B_1151',
#   'List_of_record_labels_starting_with_L_72e2'),
#  ('List_of_record_labels_starting_with_B_1151',
#   'List_of_record_labels_starting_with_N_f356'),
#  ('List_of_record_labels_starting_with_B_1151',
#   'List_of_record_labels_starting_with_V_2f53'),
#  ('List_of_record_labels_starting_with_B_1151',
#   'List_of_record_labels_starting_with_A_3d29'),
#  ('List_of_record_labels_starting_with_B_1151',
#   'List_of_record_labels_starting_with_Y_9bcd'),
#  ('List_of_record_labels_starting_with_B_1151',
#   'List_of_record_labels_starting_with_W_0deb'),
#  ('List_of_record_labels_starting_with_B_1151',
#   'List_of_record_labels_starting_with_T_d0f4'),
#  ('List_of_record_labels_starting_with_B_1151',
#   'List_of_record_labels_starting_with_U_f2ad'),
#  ('Khalid_ibn_al-Walid_cc3b', 'Abu_Bakr_b9a5'),
#  ('Khalid_ibn_al-Walid_cc3b', 'Mecca'),
#  ('Khalid_ibn_al-Walid_cc3b', 'Khalid_ibn_al-Walid_cc3b'),
#  ('Khalid_ibn_al-Walid_cc3b', 'Tactic'),
#  ('Khalid_ibn_al-Walid_cc3b', 'Strategy'),
#  ('Khalid_ibn_al-Walid_cc3b', 'Arab'),
#  ('Khalid_ibn_al-Walid_cc3b', 'Arabian_Peninsula_3421'),
#  ('Khalid_ibn_al-Walid_cc3b', 'Quraysh'),
#  ('Khalid_ibn_al-Walid_cc3b', 'Muhammad'),
#  ('Khalid_ibn_al-Walid_cc3b', 'Byzantine_Empire_38f2'),
#  ('Khalid_ibn_al-Walid_cc3b', 'Persian_Empire_bdcb'),
#  ('Khalid_ibn_al-Walid_cc3b', 'Arabic_language'),
#  ('Khalid_ibn_al-Walid_cc3b', 'Sassanid_Empire_b8bc'),
#  ('Khalid_ibn_al-Walid_cc3b', 'Roman_Empire_411e'),
#  ('Khalid_ibn_al-Walid_cc3b', 'Medina'),
#  ('Khalid_ibn_al-Walid_cc3b', 'Battle_of_Uhud_51d2'),
#  ('Toni_Braxton_1c73', 'RIAA_104b'),
#  ('Toni_Braxton_1c73', 'Toni_Braxton_1c73'),
#  ('Toni_Braxton_1c73', '1967'),
#  ('Toni_Braxton_1c73', 'Songwriter'),
#  ('Toni_Braxton_1c73', 'Singer'),
#  ('Toni_Braxton_1c73', 'October_7'),
#  ('Toni_Braxton_1c73', 'United_States_09d4'),
#  ('Toni_Braxton_1c73', 'Alto'),
#  ('Toni_Braxton_1c73', 'Actor'),
#  ('Toni_Braxton_1c73', 'Maryland'),
#  ('Toni_Braxton_1c73', 'Timbre'),
#  ('Toni_Braxton_1c73', 'Grammy_Award_0dda'),
#  ('Toni_Braxton_1c73', 'Rhythm_and_blues'),
#  ('Enrique_Gaspar_y_Rimbau_4dd3', 'Writer'),
#  ('Enrique_Gaspar_y_Rimbau_4dd3', 'Diplomat'),
#  ('Enrique_Gaspar_y_Rimbau_4dd3', 'Spain'),
#  ('Enrique_Gaspar_y_Rimbau_4dd3', '1902'),
#  ('Enrique_Gaspar_y_Rimbau_4dd3', '1842'),
#  ('Enrique_Gaspar_y_Rimbau_4dd3', 'Enrique_Gaspar_y_Rimbau_4dd3'),
#  ('Enrique_Gaspar_y_Rimbau_4dd3', 'September_7'),
#  ('Enrique_Gaspar_y_Rimbau_4dd3', 'March_2'),
#  ('Enrique_Gaspar_y_Rimbau_4dd3', 'Madrid'),
#  ('Bacon', 'Francis_Bacon_d51b'),
#  ('Bacon', 'Pig'),
#  ('Bacon', 'Bacon'),
#  ('Bacon', 'Fry'),
#  ('Bacon', 'Grill_(cooking)'),
#  ('Bacon', 'Meat'),
#  ('Bacon', 'Canada'),
#  ('Bacon', 'Pork'),
#  ('Armenian', 'Armenian_language'),
#  ('Armenian', 'Armenian_Catholic_Church_55d3'),
#  ('Armenian', 'Kingdom_of_Armenia_f6ff'),
#  ('Armenian', 'Armenian_Quarter_3c0c'),
#  ('Armenian', 'Armenian_Kingdom_of_Cilicia_ea36'),
#  ('Armenian', 'Orontid_Dynasty_e6f9'),
#  ('Armenian', 'Armenian'),
#  ('Armenian', 'Armenia'),
#  ('Armenian', 'Arminianism'),
#  ('Armenian', 'Armenian_Apostolic_Church_5de4'),
#  ('Armenian', 'Armenian_alphabet'),
#  ('Armenian', 'Armenian_Highland_cca5'),
#  ('Armenian', 'Armenian_Genocide_187a'),
#  ('Armenian', 'Armenians'),
#  ('Armenian', 'Armenian_Evangelical_Church_bc88'),
#  ('Here_I_Stand_8ea7', 'Kanye_West_f668'),
#  ('Here_I_Stand_8ea7', 'Here_I_Stand_8ea7'),
#  ('Here_I_Stand_8ea7', 'Jay-Z_fefb'),
#  ('Here_I_Stand_8ea7', 'Love_in_This_Club_Part_II_7777'),
#  ('Here_I_Stand_8ea7', 'Beyoncé'),
#  ('Here_I_Stand_8ea7', 'Timbaland'),
#  ('Here_I_Stand_8ea7', 'Usher'),
#  ('Boer', 'Europe'),
#  ('Boer', '1880'),
#  ('Boer', 'South_Africa_1287'),
#  ('Boer', '1902'),
#  ('Boer', '1881'),
#  ('Boer', 'International_Phonetic_Alphabet_96f8'),
#  ('Boer', 'Transvaal'),
#  ('Boer', '1657'),
#  ('Boer', 'Boer_War_c1b1'),
#  ('Boer', 'South'),
#  ('Boer', 'Rhodesia'),
#  ('Boer', '1696'),
#  ('Boer', '1899'),
#  ('Boer', 'Boer'),
#  ('Boer', '1707'),
#  ('Boer', 'Farmer'),
#  ('Boer', 'Dutch_language'),
#  ('Boer', 'Great_Britain_b139'),
#  ('Boer', 'Swaziland'),
#  ('804_Hispania_498a', '2005'),
#  ('804_Hispania_498a', 'Albedo'),
#  ('804_Hispania_498a', 'Temperature'),
#  ('804_Hispania_498a', 'Eccentricity_(orbit)'),
#  ('804_Hispania_498a', 'Argument_of_perihelion'),
#  ('804_Hispania_498a', 'Asteroid_spectral_types'),
#  ('804_Hispania_498a', 'Day'),
#  ('804_Hispania_498a', '805_Hormuthia_7ba7'),
#  ('804_Hispania_498a', '804_Hispania_498a'),
#  ('804_Hispania_498a', 'Longitude_of_the_ascending_node'),
#  ('804_Hispania_498a', 'Epoch_(astronomy)'),
#  ('804_Hispania_498a', 'Geometric_albedo'),
#  ('804_Hispania_498a', 'Mass'),
#  ('804_Hispania_498a', 'Giga'),
#  ('804_Hispania_498a', 'Rotation_period'),
#  ('804_Hispania_498a', 'Kelvin'),
#  ('804_Hispania_498a', 'Mean_anomaly'),
#  ('804_Hispania_498a', 'March_20'),
#  ('804_Hispania_498a', '803_Picka_5e06'),
#  ('804_Hispania_498a', 'Inclination'),
#  ('804_Hispania_498a', 'Spaniard'),
#  ('804_Hispania_498a', 'Semimajor_axis'),
#  ('804_Hispania_498a', 'Trojan_asteroid'),
#  ('804_Hispania_498a', 'Astronomical_unit'),
#  ('804_Hispania_498a', 'Second'),
#  ('804_Hispania_498a', 'Neptune_Trojan_fbc0'),
#  ('804_Hispania_498a', '20_March_0a8d'),
#  ('804_Hispania_498a', 'Minor_planet'),
#  ('804_Hispania_498a', 'Metre'),
#  ('804_Hispania_498a', '18_August_0a1b'),
#  ('804_Hispania_498a', 'Orbital_speed'),
#  ('804_Hispania_498a', 'Sun'),
#  ('804_Hispania_498a', 'Kuiper_belt'),
#  ('804_Hispania_498a', 'Escape_velocity'),
#  ('804_Hispania_498a', 'Spain'),
#  ('804_Hispania_498a', 'Aphelion'),
#  ('804_Hispania_498a', 'Comet'),
#  ('804_Hispania_498a', 'Density'),
#  ('804_Hispania_498a', 'Near-Earth_asteroid_7398'),
#  ('804_Hispania_498a', '1915'),
#  ('804_Hispania_498a', 'Julian_day'),
#  ('804_Hispania_498a', 'Degree_(angle)'),
#  ('804_Hispania_498a', 'Asteroid_belt'),
#  ('804_Hispania_498a', 'Perihelion'),
#  ('804_Hispania_498a', 'Julian_year_(astronomy)'),
#  ('804_Hispania_498a', 'Gravity'),
#  ('804_Hispania_498a', 'Standard_asteroid_physical_characteristics'),
#  ('804_Hispania_498a', 'Orbital_period'),
#  ('804_Hispania_498a', 'Absolute_magnitude'),
#  ('804_Hispania_498a', 'Oort_cloud'),
#  ('804_Hispania_498a', 'Barcelona'),
#  ('Arachnophobia', 'Arachnophobia'),
#  ('Arachnophobia', 'Spider'),
#  ('Arachnophobia', 'Phobia'),
#  ('Arachnophobia', 'Fear'),
#  ('Hibiscus_syriacus', 'Europe'),
#  ('Hibiscus_syriacus', 'Korea'),
#  ('Hibiscus_syriacus', 'Japan'),
#  ('Hibiscus_syriacus', 'Garden'),
#  ('Hibiscus_syriacus', 'Flowering_plant'),
#  ('Hibiscus_syriacus', 'Asia'),
#  ('Hibiscus_syriacus', 'Magnoliopsida'),
#  ('Hibiscus_syriacus', 'Hibiscus_syriacus'),
#  ('Hibiscus_syriacus', 'Japanese_tea_ceremony'),
#  ('Hibiscus_syriacus', 'Tree'),
#  ('Hibiscus_syriacus', 'Shrub'),
#  ('Hibiscus_syriacus', 'Hibiscus'),
#  ('Hibiscus_syriacus', 'Syria'),
#  ('Hibiscus_syriacus', 'Binomial_nomenclature'),
#  ('Hibiscus_syriacus', 'Plant'),
#  ('Hibiscus_syriacus', 'English_language'),
#  ('Hibiscus_syriacus', 'China'),
#  ('Hibiscus_syriacus', 'Scientific_classification'),
#  ('Hibiscus_syriacus', 'Carolus_Linnaeus_b3d7'),
#  ('Hibiscus_syriacus', 'Flower'),
#  ('Rosa_Luxemburg_f445', '1919'),
#  ('Rosa_Luxemburg_f445', 'January_15'),
#  ('Rosa_Luxemburg_f445', 'Germany'),
#  ('Rosa_Luxemburg_f445', 'Poland'),
#  ('Rosa_Luxemburg_f445', 'Marxism'),
#  ('Rosa_Luxemburg_f445', 'Wikiquote'),
#  ('Rosa_Luxemburg_f445', 'Jewish'),
#  ('Rosa_Luxemburg_f445', 'March_5'),
#  ('Rosa_Luxemburg_f445', '1870'),
#  ('Rosa_Luxemburg_f445', 'Rosa_Luxemburg_f445'),
#  ('Rosa_Luxemburg_f445', '1871'),
#  ('Universal_suffrage', 'Universal_suffrage'),
#  ('Universal_suffrage', 'Demonstration'),
#  ('Hornussen,_Aargau_bdd4', 'Switzerland'),
#  ('Hornussen,_Aargau_bdd4', 'Zeihen'),
#  ('Hornussen,_Aargau_bdd4', 'Ittenthal'),
#  ('Hornussen,_Aargau_bdd4', 'Municipality'),
#  ('Hornussen,_Aargau_bdd4', 'Geographic_coordinates'),
#  ('Hornussen,_Aargau_bdd4', 'Metre'),
#  ('Hornussen,_Aargau_bdd4', 'Area'),
#  ('Hornussen,_Aargau_bdd4', 'Frick,_Switzerland_ff90'),
#  ('Hornussen,_Aargau_bdd4', 'Cantons_of_Switzerland_98b4'),
#  ('Hornussen,_Aargau_bdd4', 'Postal_code_(Switzerland)_c006'),
#  ('Hornussen,_Aargau_bdd4', 'District'),
#  ('Hornussen,_Aargau_bdd4', 'As_of_December_2006_d02d'),
#  ('Hornussen,_Aargau_bdd4', 'Geographic_coordinate_system'),
#  ('Hornussen,_Aargau_bdd4', 'Elfingen'),
#  ('Hornussen,_Aargau_bdd4', 'Hornussen,_Aargau_bdd4'),
#  ('Hornussen,_Aargau_bdd4', 'Community_Identification_Number_a14c'),
#  ('Hornussen,_Aargau_bdd4', 'Elevation'),
#  ('Hornussen,_Aargau_bdd4', 'Foot_(unit_of_length)'),
#  ('Hornussen,_Aargau_bdd4', 'Bözen'),
#  ('Hornussen,_Aargau_bdd4', 'Districts_of_Switzerland_ff6d'),
#  ('Hornussen,_Aargau_bdd4', 'Sulz,_Aargau_0ea8'),
#  ('Hornussen,_Aargau_bdd4', 'Population'),
#  ('Hornussen,_Aargau_bdd4', '1_E6_m²_4409'),
#  ('Hornussen,_Aargau_bdd4', 'Ueken'),
#  ('Hornussen,_Aargau_bdd4', 'Aargau'),
#  ('Hornussen,_Aargau_bdd4', 'Canton_of_Aargau_0626'),
#  ('Hornussen,_Aargau_bdd4', 'List_of_countries'),
#  ('Hornussen,_Aargau_bdd4', 'Laufenburg_(district)'),
#  ('Hornussen,_Aargau_bdd4', 'List_of_municipalities_in_Switzerland_e702'),
#  ('Radioactive_decay', 'Nucleus_(physics)'),
#  ('Radioactive_decay', 'Radioactive_decay'),
#  ('Radioactive_decay', 'Centimeter'),
#  ('Radioactive_decay', 'Gamma_ray'),
#  ('Radioactive_decay', 'Bacteria'),
#  ('Radioactive_decay', 'Neutrino'),
#  ('Radioactive_decay', 'Neutron'),
#  ('Radioactive_decay', 'Proton'),
#  ('Radioactive_decay', 'Plutonium'),
#  ('Radioactive_decay', 'Element'),
#  ('Radioactive_decay', 'Isotope'),
#  ('Radioactive_decay', 'Uranium'),
#  ('Radioactive_decay', 'Radium'),
#  ('Radioactive_decay', 'English_language'),
#  ('Radioactive_decay', 'Angular_momentum'),
#  ('Radioactive_decay', 'Positron'),
#  ('Radioactive_decay', 'Thorium'),
#  ('Microform', 'Photographic_film'),
#  ('Microform', 'Image'),
#  ('Microform', 'Microform'),
#  ('Microform', 'Document'),
#  ('Cambridge', 'Sheffield'),
#  ('Cambridge', 'York'),
#  ('Cambridge', 'Leicester'),
#  ('Cambridge', 'Canterbury'),
#  ('Cambridge', 'Derby,_Derbyshire_7f82'),
#  ('Cambridge', 'Bath,_Somerset_c16f'),
#  ('Cambridge', 'Sunderland'),
#  ('Cambridge', 'Truro'),
#  ('Cambridge', 'Ripon'),
#  ('Cambridge', 'Salford'),
#  ('Cambridge', 'Plymouth'),
#  ('Cambridge', 'Bristol'),
#  ('Cambridge', 'City_status_in_the_United_Kingdom_d209'),
#  ('Cambridge', 'Hereford'),
#  ('Cambridge', 'Lichfield'),
#  ('Cambridge', 'Kingston_upon_Hull_19f8'),
#  ('Cambridge', 'Cambridge'),
#  ('Cambridge', 'Brighton'),
#  ('Cambridge', 'Winchester'),
#  ('Cambridge', 'Exeter'),
#  ('Cambridge', 'Stoke-on-Trent_bd53'),
#  ('Cambridge', 'England'),
#  ('Cambridge', 'City'),
#  ('Cambridge', 'Manchester'),
#  ('Cambridge', 'Liverpool,_England_7a62'),
#  ('Cambridge', 'City_of_Bradford_d4c6'),
#  ('Cambridge', 'St._Albans_761c'),
#  ('Cambridge', 'London'),
#  ('Cambridge', 'Oxford'),
#  ('Cambridge', 'Chester'),
#  ('Cambridge', 'City_of_London_c553'),
#  ('Cambridge', 'Newcastle_upon_Tyne_155c'),
#  ('Cambridge', 'Wells'),
#  ('Cambridge', 'Ely,_Cambridgeshire_bf37'),
#  ('Cambridge', 'Coventry'),
#  ('Cambridge', 'Southampton'),
#  ('Cambridge', 'Lincoln,_Lincolnshire_34d3'),
#  ('Cambridge', 'Chichester'),
#  ('Cambridge', 'Gloucester'),
#  ('Cambridge', 'Salisbury'),
#  ('Cambridge', 'Leeds'),
#  ('Cambridge', 'City_of_Wakefield_2e12'),
#  ('Cambridge', 'Preston'),
#  ('Cambridge', 'City_of_Westminster_d04f'),
#  ('Cambridge', 'Nottingham'),
#  ('Cambridge', 'Carlisle'),
#  ('Cambridge', 'City_of_Lancaster_c952'),
#  ('Cambridge', 'Norwich,_England_ff0e'),
#  ('Cambridge', 'Wolverhampton'),
#  ('Cambridge', "Addenbrooke's_Hospital_0682"),
#  ('Cambridge', 'Portsmouth'),
#  ('Cambridge', 'Peterborough'),
#  ('Cambridge', 'Worcester'),
#  ('Cambridge', 'Birmingham'),
#  ('Cambridge', 'City_of_Durham_8273'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'Homorodul_Mare_River_85f8'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'Tismana_River_49a9'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'Strei_River_42f6'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'List_of_rivers_of_Romania_(G)_1e12'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'List_of_rivers_of_Romania_(M)_5069'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'Buzău_River_032e'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'List_of_rivers_of_Romania_(Vaca_-_Valea_Neagră)_0d7a'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'Danube'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'List_of_rivers_of_Romania_(Cabii_-_Cheagu)_587f'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'Motru_River_6e3a'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'List_of_rivers_of_Romania_(Valea_Neagră_-_Vurpăr)_2a56'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'Olt_River_84d0'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'Mureş_River_77a0'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'List_of_rivers_of_Romania_(I)_3ee0'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'List_of_rivers_of_Romania_(Borşa_-_Buzunosu)_a71e'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'Putna_River_(Moldova)_47b8'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'Bicaz_River_cbbd'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'Râul_Negru_1912'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'Frumoasa_River_(Olt)_0a89'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'Aita_River_23eb'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'List_of_rivers_of_Romania_(U)_1c78'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'Telciu_River_41da'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'Homorod_River_(Dumbrăviţa)_e833'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'Rebra_River_d39c'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'List_of_rivers_of_Romania_(H)_aee2'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'Doftana_River_(Prahova)_aa53'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'Feernic_River_32d1'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'Jijia_River_(Prut)_4cfb'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'Prahova_River_d9c1'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'List_of_rivers_of_Romania_(Padeş_-_Pârâul_Lung)_92b5'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'List_of_rivers_of_Romania_(Z)_0480'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'List_of_rivers_of_Romania_(Baba_-_Boroşoaia)_877c'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'Arieş_River_(Mureş)_b607'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'Putna_River_(Siret)_2693'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'Var_River_(Olt)_4b0c'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'Telejenel_River_c867'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'List_of_rivers_of_Romania_(A)_c110'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'Jiu_River_0a4f'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'List_of_rivers_of_Romania_(Petriceni_-_Puzdra)_8131'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'Şimon_River_0a16'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'List_of_rivers_of_Romania_(J-L)_fabe'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'List_of_rivers_of_Romania_(R)_1c6b'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'Timiş_River_(Danube)_8fc0'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'List_of_rivers_of_Romania_(Comori_-_Cvaşniţa)_7dd5'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'List_of_rivers_of_Romania_(D-E)_8f53'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'Vasilatu_River_491c'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'Muereasca_River_5a5d'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'Camenca_River_f3a6'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'List_of_rivers_of_Romania_(S)_a87d'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'List_of_rivers_of_Romania_(Checheţ_-_Comoara)_552a'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'Romania'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'Baraolt_River_39f1'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'Nera_River_8dc1'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'Bistriţa_River_(Siret)_4ca7'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'List_of_rivers_of_Romania_(Ş)_079f'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'Cavnic_River_1398'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'Lotru_River_fcc0'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'List_of_rivers_of_Romania_(T)_3f84'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'List_of_rivers_of_Romania_(F)_3cc2'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'Bega_River_(Tisza)_33a8'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'List_of_rivers_of_Romania_(N-O)_2e3f'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'Gilort_River_546b'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'Holbav_River_d1c8'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'Avrig_River_b998'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'Crişul_Alb_River_8dcc'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'Covasna_County_2872'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'Dâmboviţa_River_7608'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'River'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'Ozunca_River_695a'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'Tumurel_River_77d6'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'List_of_rivers_of_Romania_(Pârâul_Lung_-_Petreasa)_5a2a'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'Râul_Mare_(Cibin)_952b'),
#  ('List_of_rivers_of_Romania_(Pade%C5%9F_-_P%C3%A2r%C3%A2ul_Lung)_92b5',
#   'Târnava_Mare_River_d3a8'),
#  ('Omar_Khayy%C3%A1m_79df', 'Omar_Khayyám_79df'),
#  ('Omar_Khayy%C3%A1m_79df', 'December_4'),
#  ('Omar_Khayy%C3%A1m_79df', 'Persian'),
#  ('Omar_Khayy%C3%A1m_79df', 'Poet'),
#  ('Omar_Khayy%C3%A1m_79df', 'Astronomer'),
#  ('Omar_Khayy%C3%A1m_79df', '1131'),
#  ('Omar_Khayy%C3%A1m_79df', 'Wikiquote'),
#  ('Omar_Khayy%C3%A1m_79df', '1048'),
#  ('Omar_Khayy%C3%A1m_79df', 'Project_Gutenberg_b9aa'),
#  ('Omar_Khayy%C3%A1m_79df', 'May_18'),
#  ('Omar_Khayy%C3%A1m_79df', 'Persian_language'),
#  ('Omar_Khayy%C3%A1m_79df', 'List_of_Persian_poets_and_authors_8273'),
#  ('Omar_Khayy%C3%A1m_79df', 'Mathematician'),
#  ('Omar_Khayy%C3%A1m_79df', 'Islamic_Golden_Age_8ccb'),
#  ('Omar_Khayy%C3%A1m_79df', 'Avicenna'),
#  ('Battle_of_Cr%C3%A9cy_7ed4', 'England'),
#  ('Battle_of_Cr%C3%A9cy_7ed4', "Hundred_Years'_War_fd8c"),
#  ('Battle_of_Cr%C3%A9cy_7ed4', '1346'),
#  ('Battle_of_Cr%C3%A9cy_7ed4', 'War'),
#  ('Battle_of_Cr%C3%A9cy_7ed4', 'Battle_of_Crécy_7ed4'),
#  ('Battle_of_Cr%C3%A9cy_7ed4', 'Tactic'),
#  ('Battle_of_Cr%C3%A9cy_7ed4', 'France'),
#  ('Battle_of_Cr%C3%A9cy_7ed4', 'Longbow'),
#  ('Battle_of_Cr%C3%A9cy_7ed4', 'Knight'),
#  ('Battle_of_Cr%C3%A9cy_7ed4', '26_August_6f8b'),
#  ('Battle_of_Cr%C3%A9cy_7ed4', 'Middle_Ages_99b9'),
#  ('Diuretic', 'Hypertension'),
#  ('Diuretic', 'Coffee'),
#  ('Diuretic', 'Bulimia_nervosa'),
#  ('Diuretic', 'Kidney'),
#  ('Diuretic', 'Diuretic'),
#  ('Diuretic', 'Alcohol'),
#  ('Diuretic', 'Herb'),
#  ('Diuretic', 'Tea'),
#  ('Diuretic', 'Heart_failure'),
#  ('Diuretic', 'Drug'),
#  ('Diuretic', 'Urine'),
#  ('Computer_printer', 'Inkjet_printer'),
#  ('Computer_printer', 'Laser_printer'),
#  ('Computer_printer', 'Pen'),
#  ('Computer_printer', 'Paper'),
#  ('Computer_printer', 'Computer_printer'),
#  ('Computer_printer', 'Computer'),
#  ('Computer_printer', 'Plotter'),
#  ('Computer_printer', 'Pin'),
#  ('Computer_printer', 'Dot-matrix_printer'),
#  ('Computer_printer', 'Ink'),
#  ('Computer_printer', 'Computer_hardware'),
#  ('169_Zelia_1f23', 'Year'),
#  ('169_Zelia_1f23', 'Albedo'),
#  ('169_Zelia_1f23', 'Trojan_asteroid'),
#  ('169_Zelia_1f23', 'Eccentricity_(orbit)'),
#  ('169_Zelia_1f23', 'Hour'),
#  ('169_Zelia_1f23', 'Oort_cloud'),
#  ('169_Zelia_1f23', 'Orbital_period'),
#  ('169_Zelia_1f23', '170_Maria_a341'),
#  ('169_Zelia_1f23', 'Kuiper_belt'),
#  ('169_Zelia_1f23', 'Camille_Flammarion_4c97'),
#  ('169_Zelia_1f23', 'Absolute_magnitude'),
#  ('169_Zelia_1f23', 'Neptune_Trojan_fbc0'),
#  ('169_Zelia_1f23', 'Aphelion'),
#  ('169_Zelia_1f23', 'September_28'),
#  ('169_Zelia_1f23', 'Asteroid'),
#  ('169_Zelia_1f23', 'Near-Earth_asteroid_7398'),
#  ('169_Zelia_1f23', '169_Zelia_1f23'),
#  ('169_Zelia_1f23', 'Rotation_period'),
#  ('169_Zelia_1f23', 'Asteroid_belt'),
#  ('169_Zelia_1f23', 'Perihelion'),
#  ('169_Zelia_1f23', 'S-type_asteroid'),
#  ('169_Zelia_1f23', 'Orbit'),
#  ('169_Zelia_1f23', 'Comet'),
#  ('169_Zelia_1f23', 'Inclination'),
#  ('169_Zelia_1f23', 'Kilometre'),
#  ('169_Zelia_1f23', 'Semimajor_axis'),
#  ('169_Zelia_1f23', 'Diameter'),
#  ('169_Zelia_1f23', '1876'),
#  ('169_Zelia_1f23', '168_Sibylla_795d'),
#  ('Algiers', 'Nairobi'),
#  ('Algiers', 'Abuja'),
#  ('Algiers', 'Senegal'),
#  ('Algiers', 'Gambia'),
#  ('Algiers', 'Malabo'),
#  ('Algiers', 'Liberia'),
#  ('Algiers', 'Dakar'),
#  ('Algiers', 'Capital_(city)'),
#  ('Algiers', 'Nouakchott'),
#  ('Algiers', 'Khartoum'),
#  ('Algiers', 'Cotonou'),
#  ('Algiers', 'Togo'),
#  ('Algiers', 'Saint_Helena_beb6'),
#  ('Algiers', 'Uganda'),
#  ('Algiers', 'Central_African_Republic_87d3'),
#  ('Algiers', 'Djibouti'),
#  ('Algiers', 'Sierra_Leone_8171'),
#  ('Algiers', 'Botswana'),
#  ('Algiers', 'Mayotte'),
#  ('Algiers', 'Cape_Town_7c7b'),
#  ('Algiers', 'Comoros'),
#  ('Algiers', 'Accra'),
#  ('Algiers', 'Gabon'),
#  ('Algiers', 'Nigeria'),
#  ('Algiers', 'Bissau'),
#  ('Algiers', 'Mali'),
#  ('Algiers', 'Cairo'),
#  ('Algiers', 'Antananarivo'),
#  ('Algiers', 'Mozambique'),
#  ('Algiers', 'Democratic_Republic_of_the_Congo_6e9c'),
#  ('Algiers', 'Zambia'),
#  ('Algiers', 'Lusaka'),
#  ('Algiers', 'Swaziland'),
#  ('Algiers', 'Guinea-Bissau_2d65'),
#  ('Algiers', 'Zimbabwe'),
#  ('Algiers', 'Mamoudzou'),
#  ('Algiers', "Côte_d'Ivoire_ed5b"),
#  ('Algiers', 'Gaborone'),
#  ('Algiers', 'Abidjan'),
#  ('Algiers', 'Lobamba'),
#  ('Algiers', 'Mogadishu'),
#  ('Algiers', 'Brazzaville'),
#  ('Algiers', 'Bamako'),
#  ('Algiers', 'Libreville'),
#  ('Algiers', 'Somalia'),
#  ('Algiers', 'Equatorial_Guinea_9382'),
#  ('Algiers', 'Banjul'),
#  ('Algiers', 'Ouagadougou'),
#  ('Algiers', 'Sudan'),
#  ('Algiers', 'Bujumbura'),
#  ('Algiers', 'Kenya'),
#  ('Algiers', 'Capital_city'),
#  ('Algiers', 'Mauritius'),
#  ('Algiers', 'Malawi'),
#  ('Algiers', 'Guinea'),
#  ('Algiers', 'Lomé'),
#  ('Algiers', "N'Djamena_83dd"),
#  ('Algiers', 'Ghana'),
#  ('Algiers', 'Angola'),
#  ('Algiers', 'Eritrea'),
#  ('Algiers', 'Algeria'),
#  ('Algiers', 'Dodoma'),
#  ('Algiers', 'Lesotho'),
#  ('Algiers', 'Ethiopia'),
#  ('Algiers', 'Lilongwe'),
#  ('Algiers', 'Chad'),
#  ('Algiers', 'Jamestown,_Saint_Helena_292e'),
#  ('Algiers', 'Niamey'),
#  ('Algiers', 'South_Africa_1287'),
#  ('Algiers', 'Kinshasa'),
#  ('Algiers', 'Kampala'),
#  ('Algiers', 'Harare'),
#  ('Algiers', 'Madagascar'),
#  ('Algiers', 'Luanda'),
#  ('Algiers', 'Maputo'),
#  ('Algiers', 'Bloemfontein'),
#  ('Algiers', 'Bangui'),
#  ('Algiers', 'Addis_Ababa_a075'),
#  ('Algiers', '...'),
#  ('Algiers', 'Egypt'),
#  ('Algiers', 'Africa'),
#  ('Algiers', 'Kigali'),
#  ('Algiers', 'Rwanda'),
#  ('Algiers', 'Niger'),
#  ('Algiers', 'Benin'),
#  ('Algiers', 'Port_Louis_6402'),
#  ('Algiers', 'Republic_of_the_Congo_91e4'),
#  ('Algiers', 'Dar_es_Salaam_5a1c'),
#  ('Algiers', 'Monrovia'),
#  ('Algiers', 'Maseru'),
#  ('Algiers', 'Mauritania'),
#  ('Algiers', 'Freetown'),
#  ('Algiers', 'Burkina_Faso_dfc4'),
#  ('Algiers', 'Population'),
#  ('Algiers', 'Moroni,_Comoros_03ac'),
#  ('Algiers', 'Burundi'),
#  ('Algiers', 'Conakry'),
#  ('Algiers', 'Djibouti_(city)'),
#  ('Algiers', 'Asmara'),
#  ('Algiers', 'Tanzania'),
#  ('Algiers', 'Mbabane'),
#  ('August_31', 'March_8'),
#  ('August_31', 'January_23'),
#  ('August_31', 'January_9'),
#  ('August_31', 'February_15'),
#  ('August_31', 'January'),
#  ('August_31', 'February_27'),
#  ('August_31', 'February_6'),
#  ('August_31', 'March_26'),
#  ('August_31', 'March_3'),
#  ('August_31', 'January_26'),
#  ('August_31', 'Wednesday'),
#  ('August_31', 'March_15'),
#  ('August_31', 'February_24'),
#  ('August_31', '2008'),
#  ('August_31', 'March_1'),
#  ('August_31', 'January_29'),
#  ('August_31', 'February_17'),
#  ('August_31', 'January_31'),
#  ('August_31', 'Monday'),
#  ('August_31', 'January_16'),
#  ('August_31', 'Tuesday'),
#  ('August_31', 'January_5'),
#  ('August_31', 'March_4'),
#  ('August_31', 'February_10'),
#  ('August_31', 'January_18'),
#  ('August_31', 'March_12'),
#  ('August_31', 'February_20'),
#  ('August_31', 'February_11'),
#  ('August_31', 'February_16'),
#  ('August_31', 'February_29'),
#  ('August_31', 'January_2'),
#  ('August_31', 'March_21'),
#  ('August_31', 'January_15'),
#  ('August_31', 'Friday'),
#  ('August_31', 'January_13'),
#  ('August_31', 'January_25'),
#  ('August_31', 'January_8'),
#  ('August_31', 'January_30'),
#  ('August_31', 'January_22'),
#  ('August_31', 'March_7'),
#  ('August_31', 'March'),
#  ('August_31', 'January_7'),
#  ('August_31', 'February_18'),
#  ('August_31', 'March_9'),
#  ('August_31', 'March_11'),
#  ('August_31', 'February_22'),
#  ('August_31', 'January_27'),
#  ('August_31', 'February_3'),
#  ('August_31', 'March_5'),
#  ('August_31', 'February_25'),
#  ('August_31', 'January_3'),
#  ('August_31', 'January_10'),
#  ('August_31', 'February_5'),
#  ('August_31', 'March_25'),
#  ('August_31', 'February_4'),
#  ('August_31', 'February_7'),
#  ('August_31', 'March_20'),
#  ('August_31', 'February_14'),
#  ('August_31', 'Calendar'),
#  ('August_31', 'January_20'),
#  ('August_31', 'January_24'),
#  ('August_31', 'January_4'),
#  ('August_31', 'March_16'),
#  ('August_31', 'March_24'),
#  ('August_31', 'March_23'),
#  ('August_31', 'March_28'),
#  ('August_31', 'March_10'),
#  ('August_31', 'March_6'),
#  ('August_31', 'January_28'),
#  ('August_31', 'January_12'),
#  ('August_31', 'February_13'),
#  ('August_31', 'January_1'),
#  ('August_31', 'February_1'),
#  ('August_31', 'February_21'),
#  ('August_31', 'March_27'),
#  ('August_31', '...'),
#  ('August_31', 'March_14'),
#  ('August_31', 'March_18'),
#  ('August_31', 'January_21'),
#  ('August_31', 'March_19'),
#  ('August_31', 'February_28'),
#  ('August_31', 'Sunday'),
#  ('August_31', 'February_19'),
#  ('August_31', 'March_22'),
#  ('August_31', 'January_19'),
#  ('August_31', 'March_2'),
#  ('August_31', 'February'),
#  ('August_31', 'February_8'),
#  ('August_31', 'February_9'),
#  ('August_31', 'January_6'),
#  ('August_31', 'March_17'),
#  ('August_31', 'January_11'),
#  ('August_31', 'January_14'),
#  ('August_31', 'February_12'),
#  ('August_31', 'March_13'),
#  ('August_31', 'February_23'),
#  ('August_31', 'Saturday'),
#  ('August_31', 'January_17'),
#  ('August_31', 'February_26'),
#  ('August_31', 'February_2'),
#  ('August_31', 'Thursday'),
#  ('1837', '1837'),
#  ('1837', '1835'),
#  ('1837', '1838'),
#  ('1837', '19th_century'),
#  ('1837', 'List_of_years'),
#  ('1837', 'Michigan'),
#  ('1837', '1830s'),
#  ('1837', '1800s'),
#  ('1837', '1836'),
#  ('1837', '1839'),
#  ('1837', '1810s'),
#  ('1837', '1860s'),
#  ('1837', '1840'),
#  ('1837', '1850s'),
#  ('1837', '1834'),
#  ('1837', '20th_century'),
#  ('1837', '1840s'),
#  ('1837', '1820s'),
#  ('1837', '18th_century'),
#  ('1837', 'List_of_decades'),
#  ('1837', 'List_of_centuries'),
#  ('D%C3%A4niken_(disambiguation)', 'Däniken,_Solothurn_8217'),
#  ('D%C3%A4niken_(disambiguation)', 'Däniken_(disambiguation)'),
#  ('D%C3%A4niken_(disambiguation)', 'Municipality'),
#  ('30_Urania_fbe4', 'Epoch_(astronomy)'),
#  ('30_Urania_fbe4', '1854'),
#  ('30_Urania_fbe4', 'Albedo'),
#  ('30_Urania_fbe4', 'Temperature'),
#  ('30_Urania_fbe4', 'Astronomical_unit'),
#  ('30_Urania_fbe4', 'Apparent_magnitude'),
#  ('30_Urania_fbe4', 'Orbital_eccentricity'),
#  ('30_Urania_fbe4', 'Apsis'),
#  ('30_Urania_fbe4', 'Kilogram'),
#  ('30_Urania_fbe4', '2006'),
#  ('30_Urania_fbe4', 'Day'),
#  ('30_Urania_fbe4', 'Semi-major_axis'),
#  ('30_Urania_fbe4', 'Longitude_of_the_ascending_node'),
#  ('30_Urania_fbe4', 'July_22'),
#  ('30_Urania_fbe4', 'Asteroid'),
#  ('30_Urania_fbe4', 'Mass'),
#  ('30_Urania_fbe4', 'Rotation_period'),
#  ('30_Urania_fbe4', 'Kelvin'),
#  ('30_Urania_fbe4', '29_Amphitrite_2840'),
#  ('30_Urania_fbe4', 'Mean_anomaly'),
#  ('30_Urania_fbe4', 'S-type_asteroid'),
#  ('30_Urania_fbe4', 'Orbit'),
#  ('30_Urania_fbe4', 'Comet'),
#  ('30_Urania_fbe4', 'Inclination'),
#  ('30_Urania_fbe4', 'Muse'),
#  ('30_Urania_fbe4', 'Greek_mythology'),
#  ('30_Urania_fbe4', 'Astronomy'),
#  ('30_Urania_fbe4', 'Surface_gravity'),
#  ('30_Urania_fbe4', 'Geometric_albedo'),
#  ('30_Urania_fbe4', '31_Euphrosyne_372b'),
#  ('30_Urania_fbe4', '30_Urania_fbe4'),
#  ('30_Urania_fbe4', 'Neptune_Trojan_fbc0'),
#  ('30_Urania_fbe4', 'Trojan_asteroid'),
#  ('30_Urania_fbe4', 'Metre'),
#  ('30_Urania_fbe4', 'Orbital_speed'),
#  ('30_Urania_fbe4', 'Kuiper_belt'),
#  ('30_Urania_fbe4', 'Escape_velocity'),
#  ('30_Urania_fbe4', 'June_14'),
#  ('30_Urania_fbe4', 'Argument_of_periapsis'),
#  ('30_Urania_fbe4', 'Giga'),
#  ('30_Urania_fbe4', 'Density'),
#  ('30_Urania_fbe4', 'Near-Earth_asteroid_7398'),
#  ('30_Urania_fbe4', 'Second'),
#  ('30_Urania_fbe4', 'Julian_day'),
#  ('30_Urania_fbe4', 'Degree_(angle)'),
#  ('30_Urania_fbe4', 'Orbital_period'),
#  ('30_Urania_fbe4', 'Julian_year_(astronomy)'),
#  ('30_Urania_fbe4', 'Cubic_centimetre'),
#  ('30_Urania_fbe4', 'Urania'),
#  ('30_Urania_fbe4', 'Asteroid_belt'),
#  ('30_Urania_fbe4', 'Absolute_magnitude'),
#  ('30_Urania_fbe4', 'Oort_cloud'),
#  ('Filament', 'Fungi'),
#  ('Filament', 'Yarn'),
#  ('Filament', 'Filamentation'),
#  ('Filament', 'Filament'),
#  ('Filament', 'Fiber'),
#  ('Filament', 'Protein_filament'),
#  ('Filament', 'Wiktionary'),
#  ('Imaginary_number', 'Whole_number'),
#  ('Imaginary_number', 'Complex_numbers'),
#  ('Imaginary_number', 'Imaginary_number'),
#  ('Buddhism', 'Dharma'),
#  ('Buddhism', 'Dhammapada'),
#  ('Buddhism', 'Bodhisattva'),
#  ('Buddhism', 'Three_Jewels_963e'),
#  ('Buddhism', 'Four_Noble_Truths_6562'),
#  ('Buddhism', 'Philosophy'),
#  ('Buddhism', 'Dalai_Lama_3904'),
#  ('Buddhism', 'Chant'),
#  ('Buddhism', 'Mongolia'),
#  ('Buddhism', 'Religion'),
#  ('Buddhism', 'China'),
#  ('Buddhism', 'Siddhartha_Gautama_3d88'),
#  ('Buddhism', '1982'),
#  ('Buddhism', 'Drug'),
#  ('Buddhism', 'Nirvana'),
#  ('Buddhism', '2001'),
#  ('Buddhism', 'Japan'),
#  ('Buddhism', 'Sanskrit'),
#  ('Buddhism', 'Enlightenment_(Buddhism)_70ae'),
#  ('Buddhism', 'Monk'),
#  ('Buddhism', '2002'),
#  ('Buddhism', 'Meditation'),
#  ('Buddhism', 'Buddhism'),
#  ('Buddhism', 'Buddha'),
#  ('Buddhism', 'India'),
#  ('Buddhism', 'Alcohol'),
#  ('Buddhism', 'Southeast_Asia_4c93'),
#  ('Buddhism', 'Noble_Eightfold_Path_12be'),
#  ('Buddhism', 'Pali'),
#  ('Buddhism', 'Central_Asia_5707'),
#  ('Buddhism', '1984'),
#  ('Buddhism', 'Gautama_Buddha_da04'),
#  ('Buddhism', 'Metta'),
#  ('Buddhism', 'Tibet'),
#  ('Buddhism', 'Congregation'),
#  ('Buddhism', 'Wikisource'),
#  ('Buddhism', 'Ritual'),
#  ('Buddhism', 'Deity'),
#  ('Buddhism', 'Prophet'),
#  ('Buddhism', 'Sri_Lanka_9993'),
#  ('Buddhism', '1990'),
#  ('Buddhism', '2003'),
#  ('Buddhism', 'Korea'),
#  ('Buddhism', 'Sangha'),
#  ('Buddhism', 'Prince'),
#  ('Ore', 'Metal'),
#  ('Ore', 'Mining'),
#  ('Ore', 'Ore'),
#  ('Ore', 'Mineral'),
#  ("Love's_Labour's_Lost_a99d", 'William_Shakespeare_c1d2'),
#  ("Love's_Labour's_Lost_a99d", '1597'),
#  ("Love's_Labour's_Lost_a99d", 'Play'),
#  ("Love's_Labour's_Lost_a99d", '1588'),
#  ("Love's_Labour's_Lost_a99d", "Love's_Labour's_Lost_a99d"),
#  ("Love's_Labour's_Lost_a99d", 'Comedy'),
#  ('Paco_de_Luc%C3%ADa_4f3c', 'Flamenco'),
#  ('Paco_de_Luc%C3%ADa_4f3c', 'Spain'),
#  ('Paco_de_Luc%C3%ADa_4f3c', '1947'),
#  ('Paco_de_Luc%C3%ADa_4f3c', 'December_21'),
#  ('Paco_de_Luc%C3%ADa_4f3c', 'Paco_de_Lucía_4f3c'),
#  ('Romford', 'London'),
#  ('Romford', 'England'),
#  ('Romford', '1153'),
#  ('Romford', 'Medieval'),
#  ('Romford', 'Market'),
#  ('Romford', 'Romford'),
#  ('John_C._Mather_c9d9', 'John_C._Mather_c9d9'),
#  ('John_C._Mather_c9d9', '1946'),
#  ('John_C._Mather_c9d9', 'Nobel_Prize_in_Physics_f6bb'),
#  ('John_C._Mather_c9d9', 'Philadelphia'),
#  ('John_C._Mather_c9d9', 'Technology'),
#  ('John_C._Mather_c9d9', 'Time_(magazine)'),
#  ('John_C._Mather_c9d9', 'Astrophysics'),
#  ('John_C._Mather_c9d9', 'Black_hole'),
#  ('John_C._Mather_c9d9', 'August_7'),
#  ('John_C._Mather_c9d9', 'United_States_09d4'),
#  ('John_C._Mather_c9d9', 'NASA_1f99'),
#  ('John_C._Mather_c9d9', 'Columbia_University_082c'),
#  ('John_C._Mather_c9d9', 'Universe'),
#  ('John_C._Mather_c9d9', 'Maryland'),
#  ('John_C._Mather_c9d9', 'George_Smoot_322d'),
#  ('John_C._Mather_c9d9', 'National_Air_and_Space_Museum_3335'),
#  ('John_C._Mather_c9d9', 'Cosmology'),
#  ('John_C._Mather_c9d9', 'Virginia'),
#  ('John_C._Mather_c9d9', 'Ph.D._5b53'),
#  ('1925', 'October_30'),
#  ('1925', '21st_century'),
#  ('1925', '1910s'),
#  ('1925', 'List_of_years'),
#  ('1925', '1926'),
#  ('1925', 'Nobel_Prize_in_Literature_c0fb'),
#  ('1925', 'November_20'),
#  ('1925', '1900s'),
#  ('1925', '1920s'),
#  ('1925', 'George_Bernard_Shaw_f7b2'),
#  ('1925', '1922'),
#  ('1925', 'List_of_decades'),
#  ('1925', '1928'),
#  ('1925', 'List_of_centuries'),
#  ('1925', 'Adolf_Hitler_fdc0'),
#  ('1925', 'December_28'),
#  ('1925', '19th_century'),
#  ('1925', '1890s'),
#  ('1925', 'January_26'),
#  ('1925', 'Television'),
#  ('1925', 'Nobel_Prize_in_Physics_f6bb'),
#  ('1925', 'March_20'),
#  ('1925', '20th_century'),
#  ('1925', 'Robert_Altman_89d1'),
#  ('1925', 'Nobel_Prize_c061'),
#  ('1925', '1923'),
#  ('1925', '1924'),
#  ('1925', 'Republic'),
#  ('1925', 'London'),
#  ('1925', 'March_25'),
#  ('1925', 'Lenny_Bruce_8f14'),
#  ('1925', 'Mein_Kampf_b165'),
#  ('1925', 'October_3'),
#  ('1925', '1950s'),
#  ('1925', 'Paul_Newman_7c26'),
#  ('1925', 'Tony_Curtis_67e1'),
#  ('1925', 'Nobel_Prize_in_Chemistry_883d'),
#  ('1925', '1925'),
#  ('1925', 'February_20'),
#  ('1925', 'January_21'),
#  ('1925', 'March_12'),
#  ('1925', 'Albania'),
#  ('1925', '1930s'),
#  ('1925', 'July_18'),
#  ('1925', 'February_8'),
#  ('1925', 'October_13'),
#  ('1925', '1927'),
#  ('1925', 'June_3'),
#  ('1925', 'NSDAP_6abb'),
#  ('1925', 'November_9'),
#  ('1925', 'Nobel_Peace_Prize_60fc'),
#  ('1925', '1940s'),
#  ('Greenville,_South_Carolina_7db2',
#   'Geographic_Names_Information_System_5bc6'),
#  ('Greenville,_South_Carolina_7db2', 'Square_kilometre'),
#  ('Greenville,_South_Carolina_7db2', 'UTC-4_d611'),
#  ('Greenville,_South_Carolina_7db2', 'Metre'),
#  ('Greenville,_South_Carolina_7db2', 'Area'),
#  ('Greenville,_South_Carolina_7db2',
#   'Political_divisions_of_the_United_States_192b'),
#  ('Greenville,_South_Carolina_7db2', 'South_Carolina_aeeb'),
#  ('Greenville,_South_Carolina_7db2', 'UTC-5_c184'),
#  ('Greenville,_South_Carolina_7db2', 'Square_mile'),
#  ('Greenville,_South_Carolina_7db2', 'Greenville,_South_Carolina_7db2'),
#  ('Greenville,_South_Carolina_7db2', 'ZIP_code_da42'),
#  ('Greenville,_South_Carolina_7db2', 'Time_zone'),
#  ('Greenville,_South_Carolina_7db2', 'Daylight_saving_time'),
#  ('Greenville,_South_Carolina_7db2', 'Elevation'),
#  ('Greenville,_South_Carolina_7db2', 'Mayor'),
#  ('Greenville,_South_Carolina_7db2', 'Foot_(unit_of_length)'),
#  ('Greenville,_South_Carolina_7db2', 'United_States_09d4'),
#  ('Greenville,_South_Carolina_7db2', 'Metropolitan_area'),
#  ('Greenville,_South_Carolina_7db2', 'North_American_Eastern_Time_Zone_d793'),
#  ('Greenville,_South_Carolina_7db2', 'Population_density'),
#  ('Greenville,_South_Carolina_7db2', 'List_of_countries'),
#  ('Greenville,_South_Carolina_7db2', 'City'),
#  ('Greenville,_South_Carolina_7db2', 'Urban_area'),
#  ('World_Health_Organization_57ba', 'Switzerland'),
#  ('World_Health_Organization_57ba', 'World_Health_Organization_57ba'),
#  ('World_Health_Organization_57ba', '1948'),
#  ('World_Health_Organization_57ba', 'April_7'),
#  ('World_Health_Organization_57ba', 'Geneva'),
#  ('World_Health_Organization_57ba', 'United_Nations_3208'),
#  ('World_Health_Organization_57ba', 'Headquarters'),
#  ('Bill_Gates_65fa', 'Microsoft'),
#  ('Bill_Gates_65fa', '1955'),
#  ('Bill_Gates_65fa', 'United_States_09d4'),
#  ('Bill_Gates_65fa', 'Sahara'),
#  ('Bill_Gates_65fa', 'Personal_computer'),
#  ('Bill_Gates_65fa', 'Billionaire'),
#  ('Bill_Gates_65fa', 'Harvard_University_9346'),
#  ('Bill_Gates_65fa', 'October_28'),
#  ('Bill_Gates_65fa', 'Vaccination'),
#  ('Bill_Gates_65fa', 'Software'),
#  ('Bill_Gates_65fa', 'Bill_Gates_65fa'),
#  ('Bill_Gates_65fa', 'CEO_8589'),
#  ('Bill_Gates_65fa', 'Africa'),
#  ('20s_BC_c0a1', 'Centuries'),
#  ('20s_BC_c0a1', '0s_BC_3e1f'),
#  ('20s_BC_c0a1', '30s_BC_20d4'),
#  ('20s_BC_c0a1', '1st_century_BC_8889'),
#  ('20s_BC_c0a1', '1st_century'),
#  ('20s_BC_c0a1', 'Caesar_Augustus_565f'),
#  ('20s_BC_c0a1', '27_BC_b403'),
#  ('20s_BC_c0a1', 'Roman_Emperor_293f'),
#  ('20s_BC_c0a1', '20s_BC_c0a1'),
#  ('20s_BC_c0a1', '40s_BC_bf00'),
#  ('20s_BC_c0a1', '14'),
#  ('20s_BC_c0a1', '2nd_century_BC_e028'),
#  ('20s_BC_c0a1', '50s_BC_e9ba'),
#  ('20s_BC_c0a1', '0s'),
#  ('20s_BC_c0a1', 'List_of_decades'),
#  ...]

# %%
length = 0 
subg = None
for subgraph in nx.strongly_connected_components(G):
    if len(subgraph) > length:
        subg = subgraph
        length = len(subgraph)

# %%
len(subg)
# Out:
# 24814

# %%
df1 = df2.ix[list(subg)]['out_links']

# %%
df1_dict = df1.to_dict()
G=nx.DiGraph(df1_dict)
# print(nx.diameter(G))

# %%
G.number_of_nodes()
# Out:
# 31980

# %%
len(df1)
# Out:
# 24814

# %%
pG = G.subgraph(subg)

# %%
print(nx.diameter(pG))
# Out:
# 41
