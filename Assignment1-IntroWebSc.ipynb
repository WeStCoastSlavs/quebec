# %%
import random
randoms = random.sample(range(0,90), 10)
randoms.sort()
print(randoms)
# Out:
# [7, 10, 19, 20, 21, 34, 53, 69, 81, 87]

# %%
import math
SIN = list(map(math.sin, randoms))
COSIN = list(map(math.cos, randoms))
print(SIN)
print(COSIN)
# Out:
# [0.6569865987187891, -0.5440211108893698, 0.14987720966295234, 0.9129452507276277, 0.8366556385360561, 0.5290826861200238, 0.39592515018183416, -0.11478481378318722, -0.6298879942744539, -0.8218178366308225]
# [0.7539022543433046, -0.8390715290764524, 0.9887046181866692, 0.408082061813392, -0.5477292602242684, -0.8485702747846052, -0.9182827862121189, 0.9933903797222716, 0.7766859820216312, 0.569750334265312]

# %%
import matplotlib.pyplot as plt
plt.scatter(randoms, SIN, label="sin", color="red")
plt.scatter(randoms, COSIN, label="cos", color="teal")
plt.ylabel('Value of Sin/Cos')
plt.xlabel('Number')
# plt.xticks(randoms, list(map(str, randoms)))
plt.legend()
plt.show()
